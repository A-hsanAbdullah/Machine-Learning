# %%
import pandas as pd

# %%
data=pd.DataFrame({"Name":['Dan', 'Joann', 'Pedro', 'Rosie', 'Ethan', 'Vicky', 'Frederic', 'Jimmie', 
                                     'Rhonda', 'Giovanni', 'Francesca', 'Rajab', 'Naiyana', 'Kian', 'Jenny',
                                     'Jakeem','Helena','Ismat','Anila','Skye','Daniel','Aisha'],
                   'Grades':[50,50,47,97,49,3,53,42,26,74,82,62,37,15,70,27,36,35,48,52,63,64],
                   'study_hours':[10.0,11.5,9.0,16.0,9.25,1.0,11.5,9.0,8.5,14.5,15.5,
               13.75,9.0,8.0,15.5,8.0,9.0,6.0,10.0,12.0,12.5,12.0]})

# %%
data
# Out:
#          Name  Grades  study_hours
# 0         Dan      50        10.00
# 1       Joann      50        11.50
# 2       Pedro      47         9.00
# 3       Rosie      97        16.00
# 4       Ethan      49         9.25
# 5       Vicky       3         1.00
# 6    Frederic      53        11.50
# 7      Jimmie      42         9.00
# 8      Rhonda      26         8.50
# 9    Giovanni      74        14.50
# 10  Francesca      82        15.50
# 11      Rajab      62        13.75
# 12    Naiyana      37         9.00
# 13       Kian      15         8.00
# 14      Jenny      70        15.50
# 15     Jakeem      27         8.00
# 16     Helena      36         9.00
# 17      Ismat      35         6.00
# 18      Anila      48        10.00
# 19       Skye      52        12.00
# 20     Daniel      63        12.50
# 21      Aisha      64        12.00

# %%
data.loc[0:4]
# Out:
#     Name  Grades  study_hours
# 0    Dan      50        10.00
# 1  Joann      50        11.50
# 2  Pedro      47         9.00
# 3  Rosie      97        16.00
# 4  Ethan      49         9.25

# %%
data.iloc[0:5]
# Out:
#     Name  Grades  study_hours
# 0    Dan      50        10.00
# 1  Joann      50        11.50
# 2  Pedro      47         9.00
# 3  Rosie      97        16.00
# 4  Ethan      49         9.25

# %%
data.loc[0]
# Out:
# Name            Dan
# Grades           50
# study_hours    10.0
# Name: 0, dtype: object

# %%
data.loc[0,'Grades']
# Out:
# 50

# %%
data.loc[data['Name']=='Aisha']
# Out:
#      Name  Grades  study_hours
# 21  Aisha      64         12.0

# %%
data[data.Name=='Aisha']
# Out:
#      Name  Grades  study_hours
# 21  Aisha      64         12.0

# %%
data.query('Name=="Aisha"')
# Out:
#      Name  Grades  study_hours
# 21  Aisha      64         12.0

# %%
new_data=pd.read_csv('grades.csv',delimiter=',')
new_data
# Out:
#          Name  StudyHours  Grade
# 0         Dan       10.00   50.0
# 1       Joann       11.50   50.0
# 2       Pedro        9.00   47.0
# 3       Rosie       16.00   97.0
# 4       Ethan        9.25   49.0
# 5       Vicky        1.00    3.0
# 6    Frederic       11.50   53.0
# 7      Jimmie        9.00   42.0
# 8      Rhonda        8.50   26.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 11      Rajab       13.75   62.0
# 12    Naiyana        9.00   37.0
# 13       Kian        8.00   15.0
# 14      Jenny       15.50   70.0
# 15     Jakeem        8.00   27.0
# 16     Helena        9.00   36.0
# 17      Ismat        6.00   35.0
# 18      Anila       10.00   48.0
# 19       Skye       12.00   52.0
# 20     Daniel       12.50   63.0
# 21      Aisha       12.00   64.0
# 22       Bill        8.00    NaN
# 23        Ted         NaN    NaN

# %%
new_data.isnull().sum()
# Out:
# Name          0
# StudyHours    1
# Grade         2
# dtype: int64

# %%
new_data[new_data.isnull().any(axis=1)]
# Out:
#     Name  StudyHours  Grade
# 22  Bill         8.0    NaN
# 23   Ted         NaN    NaN

# %%
new_data.dropna(axis=0,how='any')
# Out:
#          Name  StudyHours  Grade
# 0         Dan       10.00   50.0
# 1       Joann       11.50   50.0
# 2       Pedro        9.00   47.0
# 3       Rosie       16.00   97.0
# 4       Ethan        9.25   49.0
# 5       Vicky        1.00    3.0
# 6    Frederic       11.50   53.0
# 7      Jimmie        9.00   42.0
# 8      Rhonda        8.50   26.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 11      Rajab       13.75   62.0
# 12    Naiyana        9.00   37.0
# 13       Kian        8.00   15.0
# 14      Jenny       15.50   70.0
# 15     Jakeem        8.00   27.0
# 16     Helena        9.00   36.0
# 17      Ismat        6.00   35.0
# 18      Anila       10.00   48.0
# 19       Skye       12.00   52.0
# 20     Daniel       12.50   63.0
# 21      Aisha       12.00   64.0

# %%
new_data=new_data.drop([22,23])

# %%
mean_grade=new_data.Grade.mean()
mean_time=new_data.StudyHours.mean()

# %%
mean_grade
# Out:
# 49.18181818181818

# %%
mean_time
# Out:
# 10.522727272727273

# %%
new_data[new_data.StudyHours>mean_time].Grade.mean()
# Out:
# 66.7

# %%
passs=pd.Series(new_data['Grade'] >= 60)
new_data=pd.concat([new_data,passs.rename("Pass")],axis=1)
new_data
# Out:
#          Name  StudyHours  Grade   Pass
# 0         Dan       10.00   50.0  False
# 1       Joann       11.50   50.0  False
# 2       Pedro        9.00   47.0  False
# 3       Rosie       16.00   97.0   True
# 4       Ethan        9.25   49.0  False
# 5       Vicky        1.00    3.0  False
# 6    Frederic       11.50   53.0  False
# 7      Jimmie        9.00   42.0  False
# 8      Rhonda        8.50   26.0  False
# 9    Giovanni       14.50   74.0   True
# 10  Francesca       15.50   82.0   True
# 11      Rajab       13.75   62.0   True
# 12    Naiyana        9.00   37.0  False
# 13       Kian        8.00   15.0  False
# 14      Jenny       15.50   70.0   True
# 15     Jakeem        8.00   27.0  False
# 16     Helena        9.00   36.0  False
# 17      Ismat        6.00   35.0  False
# 18      Anila       10.00   48.0  False
# 19       Skye       12.00   52.0  False
# 20     Daniel       12.50   63.0   True
# 21      Aisha       12.00   64.0   True

# %%
new_data.groupby(new_data.Pass)[['StudyHours','Grade']].mean()
# Out:
#        StudyHours      Grade
# Pass
# False    8.783333  38.000000
# True    14.250000  73.142857

# %%
new_data.describe()
# Out:
#        StudyHours      Grade
# count   22.000000  22.000000
# mean    10.522727  49.181818
# std      3.487144  21.737912
# min      1.000000   3.000000
# 25%      9.000000  36.250000
# 50%     10.000000  49.500000
# 75%     12.375000  62.750000
# max     16.000000  97.000000

# %%
from matplotlib import pyplot as pplot
import numpy as np
from math import sqrt

# %%
X=np.arange(1,11)
Y1=2*(X)
Y2=3*X

# %%
pplot.subplot(1,2,1)
pplot.plot(X,Y1,color='g',linestyle='-',linewidth=2)
pplot.title("X verses Y Graph",color='r')
pplot.xlabel("X_Axis",color='b')
pplot.ylabel("Y_Axis",color='b')
pplot.grid(True)
pplot.subplot(1,2,2)
pplot.plot(X,Y2,color='r',linestyle='--',linewidth=1)
pplot.title("X verses Y Graph",color='r')
pplot.xlabel("X_Axis",color='b')
pplot.ylabel("Y_Axis",color='b')
pplot.grid(True)
pplot.show()

# %%
import pandas as pd
data=pd.read_csv('grades.csv',delimiter=',')
data
# Out:
#          Name  StudyHours  Grade
# 0         Dan       10.00   50.0
# 1       Joann       11.50   50.0
# 2       Pedro        9.00   47.0
# 3       Rosie       16.00   97.0
# 4       Ethan        9.25   49.0
# 5       Vicky        1.00    3.0
# 6    Frederic       11.50   53.0
# 7      Jimmie        9.00   42.0
# 8      Rhonda        8.50   26.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 11      Rajab       13.75   62.0
# 12    Naiyana        9.00   37.0
# 13       Kian        8.00   15.0
# 14      Jenny       15.50   70.0
# 15     Jakeem        8.00   27.0
# 16     Helena        9.00   36.0
# 17      Ismat        6.00   35.0
# 18      Anila       10.00   48.0
# 19       Skye       12.00   52.0
# 20     Daniel       12.50   63.0
# 21      Aisha       12.00   64.0
# 22       Bill        8.00    NaN
# 23        Ted         NaN    NaN

# %%
data=data.dropna(axis=0)
data
# Out:
#          Name  StudyHours  Grade   Pass
# 0         Dan       10.00   50.0  False
# 1       Joann       11.50   50.0  False
# 2       Pedro        9.00   47.0  False
# 3       Rosie       16.00   97.0   True
# 4       Ethan        9.25   49.0  False
# 5       Vicky        1.00    3.0  False
# 6    Frederic       11.50   53.0  False
# 7      Jimmie        9.00   42.0  False
# 8      Rhonda        8.50   26.0  False
# 9    Giovanni       14.50   74.0   True
# 10  Francesca       15.50   82.0   True
# 11      Rajab       13.75   62.0   True
# 12    Naiyana        9.00   37.0  False
# 13       Kian        8.00   15.0  False
# 14      Jenny       15.50   70.0   True
# 15     Jakeem        8.00   27.0  False
# 16     Helena        9.00   36.0  False
# 17      Ismat        6.00   35.0  False
# 18      Anila       10.00   48.0  False
# 19       Skye       12.00   52.0  False
# 20     Daniel       12.50   63.0   True
# 21      Aisha       12.00   64.0   True

# %%
passs=pd.Series(data['Grade']>60)
data=pd.concat([data,passs.rename("Pass")],axis=1)

# %%
data
# Out:
#          Name  StudyHours  Grade   Pass
# 0         Dan       10.00   50.0  False
# 1       Joann       11.50   50.0  False
# 2       Pedro        9.00   47.0  False
# 3       Rosie       16.00   97.0   True
# 4       Ethan        9.25   49.0  False
# 5       Vicky        1.00    3.0  False
# 6    Frederic       11.50   53.0  False
# 7      Jimmie        9.00   42.0  False
# 8      Rhonda        8.50   26.0  False
# 9    Giovanni       14.50   74.0   True
# 10  Francesca       15.50   82.0   True
# 11      Rajab       13.75   62.0   True
# 12    Naiyana        9.00   37.0  False
# 13       Kian        8.00   15.0  False
# 14      Jenny       15.50   70.0   True
# 15     Jakeem        8.00   27.0  False
# 16     Helena        9.00   36.0  False
# 17      Ismat        6.00   35.0  False
# 18      Anila       10.00   48.0  False
# 19       Skye       12.00   52.0  False
# 20     Daniel       12.50   63.0   True
# 21      Aisha       12.00   64.0   True

# %%
pplot.bar(x=data.Name,height=data.Grade)
pplot.show()

# %%
pplot.bar(x=data.Name, height=data.Grade, color='orange')

# Customize the chart
pplot.title('Student Grades')
pplot.xlabel('Student')
pplot.ylabel('Grade')
pplot.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
pplot.xticks(rotation=90)

# Display the plot
pplot.show()

# %%
fig= pplot.figure(figsize=(8,2))
pplot.bar(x=data.Name,height=data.Grade,color='g')
pplot.xlabel("Student",color='r')
pplot.ylabel("Grades",color='r')
pplot.title("Students Grades",color='r')
pplot.xticks(rotation=90)
pplot.grid(True,color='y',linestyle='--',linewidth=1,axis='y',alpha=0.9)
pplot.show()

# %%
fig , ax =pplot.plot()
# pplot.bar(x=data.Name,height=data.Grade,color='g')
# pplot.xlabel("Student",color='r')
# pplot.ylabel("Grades",color='r')
# pplot.title("Students Grades",color='r')
# pplot.xticks(rotation=90)

# pplot.subplot(1,2,2)
# pass_counts = data['Pass'].value_counts()
# pplot.pie(pass_counts, labels=pass_counts)
# pplot.title('Passing Grades')
# pplot.legend(pass_counts.keys().tolist())
# pplot.grid(True,color='y',linestyle='--',linewidth=1,axis='y',alpha=0.9)
# pplot.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 pplot.subplot(1,2,figsize=(10,2))
#       2 pplot.bar(x=data.Name,height=data.Grade,color='g')
#       3 pplot.xlabel("Student",color='r')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\pyplot.py:1529, in subplot(*args, **kwargs)
#    1526 fig = gcf()
#    1528 # First, search for an existing subplot with a matching spec.
# -> 1529 key = SubplotSpec._from_subplot_args(fig, args)
#    1531 for ax in fig.axes:
#    1532     # If we found an Axes at the position, we can reuse it if the user passed no
#    1533     # kwargs or if the Axes class and kwargs are identical.
#    1534     if (ax.get_subplotspec() == key
#    1535         and (kwargs == {}
#    1536              or (ax._projection_init
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 hello
#
# NameError: name 'hello' is not defined

# %%
import matplotlib as pplot
X=[20 , 90 , 30 , 40, 10]
Y=[1,4,6,8,9]
pplot.sc

# %%
import pandas as pd

# Data provided
data = {
    "Vehicle": ["Suzuki", "Suzuki", "Suzuki", "Suzuki", "Suzuki", "Suzuki", "Suzuki", "Suzuki", "Suzuki Pickup", "Suzuki Pickup", "Suzuki Pickup",
                "Loader", "Loader", "Loader", "Loader", "Loader", "Shazor", "Shazor", "Shazor", "Shazor", "Shazor", "Shazor", "Shazor", "Shazor",
                "Shazor", "Shazor", "Shazor", "Shazor", "Shazor", "Mazda 14 ft", "Master", "Master", "Others"],
    "Name": ["Rizwan", "Amjad", "Amjad", "Zulfi Husain", "Zaryab", "Imran", "Haris", "Tasleem abass", "Atif", "Azkar shah", "Allahzad",
             "Faiz", "Mewa", "Habibuallah", "Usman", "Fasil", "Ahmed Ali", "Shafer ikhtar", "Ijaz bhatti", "Deen Muhammad", "Wali Khan",
             "Sawar Khan", "Shokhat", "Naseem abass", "Sarfraz", "Sheraz", "Nasir", "Saif Ali", "Danial", "Arsah", "Johj"],
    "Mobile": ["03225215327", "03135672579", "03155264870", "03115058384", "03121530577", "03447022701", "03088781820", "03109307004", "03135249199",
               "03129553703", "0305150801", "03105608191", "03165400189", "03081059594", "03165752525", "03419448352", "03119605169", "03105102956",
               "03011543791", "03117591006", "03461718422", "03198626504", "0300 5301058", "03132272562", "03130502013", "03131555005", "03105694944",
               "03045152782", "03155264870", "03155350095", "03115146918"]
}

# Creating a DataFrame
df = pd.DataFrame(data)

# Splitting DataFrame into sections
suzuki_section = df[df['Vehicle'].str.contains("Suzuki")]
loader_section = df[df['Vehicle'].str.contains("Loader")]
shazor_section = df[df['Vehicle'].str.contains("Shazor")]
others_section = df[~df['Vehicle'].str.contains("Suzuki|Loader|Shazor")]

# Saving to Excel with sections
with pd.ExcelWriter('/mnt/data/vehicles.xlsx') as writer:
    suzuki_section.to_excel(writer, sheet_name='Suzuki', index=False)
    loader_section.to_excel(writer, sheet_name='Loader', index=False)
    shazor_section.to_excel(writer, sheet_name='Shazor', index=False)
    others_section.to_excel(writer, sheet_name='Others', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pplot.scatter(X,Y)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\_api\__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'scatter'

# %%
x= ["Rizwan", "Amjad", "Amjad", "Zulfi Husain", "Zaryab", "Imran", "Haris", "Tasleem abass", "Atif", "Azkar shah", "Allahzad",
             "Faiz", "Mewa", "Habibuallah", "Usman", "Fasil", "Ahmed Ali", "Shafer ikhtar", "Ijaz bhatti", "Deen Muhammad", "Wali Khan",
             "Sawar Khan", "Shokhat", "Naseem abass", "Sarfraz", "Sheraz", "Nasir", "Saif Ali", "Danial", "Arsah", "Johj"]

# %%
len(x)
# Out:
# 31
